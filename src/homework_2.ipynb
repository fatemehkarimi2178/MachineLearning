# %% [markdown]
# #
#
# - **Answer Set** : NO. 02
# - **Full Name** : Fatemeh Karimi Barikarasfi
# - **Student Code** : 610301060

# %% [markdown]
# The goal is to use LDA for dimentionality reduction and then use Perⅽeptron classifier.

# %% [markdown]
# ## 1.
#
# ### Importing Needed Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import Perceptron
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### a.
#
# **Question:** Scatter the training data by taking into the account of the class of each data.
#
# Load the dataset:

# %%
train_set = pd.read_csv('train.csv')
test_set = pd.read_csv('test.csv')

# %% [markdown]
# Scatter the training data:

# %%
plt.scatter(train_set.x0, train_set.x1, c = train_set.target)
plt.show()

# %% [markdown]
# ### b.
#
# **Question:** Normalize the datasets according to the training data.

# %%
x_train = np.array(train_set[['x0', 'x1']])
x_test = np.array(test_set[['x0', 'x1']])

y_train = np.array(train_set['target'])

scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)

# %% [markdown]
# ### c.
#
# **Question:** Fit polynomial feature extractor with degree = 5, 10, 15, 20, 25 on the datasets. Then, using LDA in each of these cases, reduce the data to a 2-dimentional space and then use the Perceptron classifier to seperate the data. Then validate all these models.

# %% [markdown]
# Generate a new feature matrix consisting of all polynomial combinations of the features with degree less than or equal to the 5, 10, 15, 20, 25:

# %%
x_train_5 = PolynomialFeatures(degree = 5)
x_train_5 = x_train_5.fit_transform(x_train)

x_train_10 = PolynomialFeatures(degree = 10)
x_train_10 = x_train_10.fit_transform(x_train)

x_train_15 = PolynomialFeatures(degree = 15)
x_train_15 = x_train_15.fit_transform(x_train)

x_train_20 = PolynomialFeatures(degree = 20)
x_train_20 = x_train_20.fit_transform(x_train)

x_train_25 = PolynomialFeatures(degree = 25)
x_train_25 = x_train_25.fit_transform(x_train)

# %% [markdown]
# Use LDA for dimentionality reduction of each feature matrices and then use Perceptron for classification:

# %% [markdown]
# #### Degree = 5

# %%
LDA_5 = LinearDiscriminantAnalysis(n_components = 2)
LDA_5.fit(x_train_5, y_train)

X_TRAIN_5 = LDA_5.transform(x_train_5)

CLF_5 = Perceptron()
CLF_5.fit(X_TRAIN_5, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Scatter the reduced features of degree = 5:

# %%
plt.scatter(X_TRAIN_5[:, 0], X_TRAIN_5[:, 1], c = y_train)
plt.show()

# %% [markdown]
# #### Degree = 10

# %%
LDA_10 = LinearDiscriminantAnalysis(n_components = 2)
LDA_10.fit(x_train_10, y_train)

X_TRAIN_10 = LDA_10.transform(x_train_10)

CLF_10 = Perceptron()
CLF_10.fit(X_TRAIN_10, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Scatter the reduced features of degree = 10:

# %%
plt.scatter(X_TRAIN_10[:, 0], X_TRAIN_10[:, 1], c = y_train)

# %% [markdown]
# #### Degree = 15

# %%
LDA_15 = LinearDiscriminantAnalysis(n_components = 2)
LDA_15.fit(x_train_15, y_train)

X_TRAIN_15 = LDA_15.transform(x_train_15)

CLF_15 = Perceptron()
CLF_15.fit(X_TRAIN_15, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Scatter the reduced features of degree = 15:

# %%
plt.scatter(X_TRAIN_15[:, 0], X_TRAIN_15[:, 1], c = y_train)

# %% [markdown]
# #### Degree = 20

# %%
LDA_20 = LinearDiscriminantAnalysis(n_components = 2)
LDA_20.fit(x_train_20, y_train)

X_TRAIN_20 = LDA_20.transform(x_train_20)

CLF_20 = Perceptron()
CLF_20.fit(X_TRAIN_20, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Scatter the reduced features of degree = 20:

# %%
plt.scatter(X_TRAIN_20[:, 0], X_TRAIN_20[:, 1], c = y_train)

# %% [markdown]
# #### Degree = 25

# %%
LDA_25 = LinearDiscriminantAnalysis(n_components = 2)
LDA_25.fit(x_train_25, y_train)

X_TRAIN_25 = LDA_25.transform(x_train_25)

CLF_25 = Perceptron()
CLF_25.fit(X_TRAIN_25, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %% [markdown]
# Scatter the reduced features of degree = 25:

# %%
plt.scatter(X_TRAIN_25[:, 0], X_TRAIN_25[:, 1], c = y_train)

# %% [markdown]
# Use repeated 5 fold cross-validation for validating each of the models above:
#
# #### Degree = 5

# %%
# Degree = 5
accuracy_train_5 = np.empty((10, 5))
accuracy_test_5 = np.empty((10, 5))

for i in range(0, 10):
  X = np.arange(0, len(x_train_5))
  kf = KFold(n_splits = 5, shuffle = True)
  j = 0
  for train, test in kf.split(X):

    LDA_5 = LinearDiscriminantAnalysis(n_components = 2)
    LDA_5.fit(x_train_5[train], y_train[train])

    X_TRAIN = LDA_5.transform(x_train_5)[train]
    X_TEST = LDA_5.transform(x_train_5)[test]
    CLF_5 = Perceptron()
    CLF_5.fit(X_TRAIN, y_train[train])

    accuracy_train_5[i][j] = accuracy_score(CLF_5.predict(X_TRAIN), y_train[train])
    accuracy_test_5[i][j] = accuracy_score(CLF_5.predict(X_TEST), y_train[test])

    j = j + 1

accuracy_train_55 = np.empty(10)
accuracy_test_55 = np.empty(10)
for i in range(0, 10):
  accuracy_train_55[i] = accuracy_train_5[i].mean()
  accuracy_test_55[i] = accuracy_test_5[i].mean()

# %% [markdown]
# #### Degree = 10

# %%
# Degree = 10
accuracy_train_10 = np.empty((10, 5))
accuracy_test_10 = np.empty((10, 5))

for i in range(0, 10):
  X = np.arange(0, len(x_train_10))
  kf = KFold(n_splits = 5, shuffle = True)
  j = 0
  for train, test in kf.split(X):

    LDA_10 = LinearDiscriminantAnalysis(n_components = 2)
    LDA_10.fit(x_train_10[train], y_train[train])

    X_TRAIN = LDA_10.transform(x_train_10)[train]
    X_TEST = LDA_10.transform(x_train_10)[test]
    CLF_10 = Perceptron()
    CLF_10.fit(X_TRAIN, y_train[train])

    accuracy_train_10[i][j] = accuracy_score(CLF_10.predict(X_TRAIN), y_train[train])
    accuracy_test_10[i][j] = accuracy_score(CLF_10.predict(X_TEST), y_train[test])

    j = j + 1

accuracy_train_1010 = np.empty(10)
accuracy_test_1010 = np.empty(10)
for i in range(0, 10):
  accuracy_train_1010[i] = accuracy_train_10[i].mean()
  accuracy_test_1010[i] = accuracy_test_10[i].mean()

# %% [markdown]
# #### Degree = 15

# %%
# Degree = 15
accuracy_train_15 = np.empty((10, 5))
accuracy_test_15 = np.empty((10, 5))

for i in range(0, 10):
  X = np.arange(0, len(x_train_5))
  kf = KFold(n_splits = 5, shuffle = True)
  j = 0
  for train, test in kf.split(X):

    LDA_15 = LinearDiscriminantAnalysis(n_components = 2)
    LDA_15.fit(x_train_15[train], y_train[train])

    X_TRAIN = LDA_15.transform(x_train_15)[train]
    X_TEST = LDA_15.transform(x_train_15)[test]
    CLF_15 = Perceptron()
    CLF_15.fit(X_TRAIN, y_train[train])

    accuracy_train_15[i][j] = accuracy_score(CLF_15.predict(X_TRAIN), y_train[train])
    accuracy_test_15[i][j] = accuracy_score(CLF_15.predict(X_TEST), y_train[test])

    j = j + 1

accuracy_train_1515 = np.empty(10)
accuracy_test_1515 = np.empty(10)
for i in range(0, 10):
  accuracy_train_1515[i] = accuracy_train_15[i].mean()
  accuracy_test_1515[i] = accuracy_test_15[i].mean()

# %% [markdown]
# #### Degree = 20

# %%
# Degree = 20
accuracy_train_20 = np.empty((10, 5))
accuracy_test_20 = np.empty((10, 5))

for i in range(0, 10):
  X = np.arange(0, len(x_train_5))
  kf = KFold(n_splits = 5, shuffle = True)
  j = 0
  for train, test in kf.split(X):

    LDA_20 = LinearDiscriminantAnalysis(n_components = 2)
    LDA_20.fit(x_train_20[train], y_train[train])

    X_TRAIN = LDA_20.transform(x_train_20)[train]
    X_TEST = LDA_20.transform(x_train_20)[test]
    CLF_20 = Perceptron()
    CLF_20.fit(X_TRAIN, y_train[train])

    accuracy_train_20[i][j] = accuracy_score(CLF_20.predict(X_TRAIN), y_train[train])
    accuracy_test_20[i][j] = accuracy_score(CLF_20.predict(X_TEST), y_train[test])

    j = j + 1

accuracy_train_2020 = np.empty(10)
accuracy_test_2020 = np.empty(10)
for i in range(0, 10):
  accuracy_train_2020[i] = accuracy_train_20[i].mean()
  accuracy_test_2020[i] = accuracy_test_20[i].mean()

# %% [markdown]
# #### Degree = 25

# %%
# Degree = 25
accuracy_train_25 = np.empty((10, 5))
accuracy_test_25 = np.empty((10, 5))

for i in range(0, 10):
  X = np.arange(0, len(x_train_25))
  kf = KFold(n_splits = 5, shuffle = True)
  j = 0
  for train, test in kf.split(X):

    LDA_25 = LinearDiscriminantAnalysis(n_components = 2)
    LDA_25.fit(x_train_25[train], y_train[train])

    X_TRAIN = LDA_25.transform(x_train_25)[train]
    X_TEST = LDA_25.transform(x_train_25)[test]
    CLF_25 = Perceptron()
    CLF_25.fit(X_TRAIN, y_train[train])

    accuracy_train_25[i][j] = accuracy_score(CLF_25.predict(X_TRAIN), y_train[train])
    accuracy_test_25[i][j] = accuracy_score(CLF_25.predict(X_TEST), y_train[test])

    j = j + 1

accuracy_train_2525 = np.empty(10)
accuracy_test_2525 = np.empty(10)
for i in range(0, 10):
  accuracy_train_2525[i] = accuracy_train_25[i].mean()
  accuracy_test_2525[i] = accuracy_test_25[i].mean()

# %% [markdown]
# Train Accuracy Boxplot:

# %%
train_accuracy = pd.DataFrame({'Degree = 5': accuracy_train_55,
                               'Degree = 10': accuracy_train_1010,
                               'Degree = 15': accuracy_train_1515,
                               'Degree = 20': accuracy_train_2020,
                               'Degree = 25': accuracy_train_2525})

# %%
train_accuracy.boxplot()

# %% [markdown]
# Test Accuracy Boxplot:

# %%
test_accuracy = pd.DataFrame({'Degree = 5': accuracy_test_55,
                               'Degree = 10': accuracy_test_1010,
                               'Degree = 15': accuracy_test_1515,
                               'Degree = 20': accuracy_test_2020,
                               'Degree = 25': accuracy_test_2525})

# %%
test_accuracy.boxplot()

# %% [markdown]
# ### c.
#
# **Question:** Determine the best degree and the make prediction on test set according to the determined model.
#
# The model with the degree = 15 is the best model.

# %%
x_test = np.array(test_set[['x0', 'x1']])
x_test = scaler.transform(x_test)
x_test_15 = PolynomialFeatures(degree = 15)
x_test_15 = x_test_15.fit_transform(x_test)


LDA_OPT = LinearDiscriminantAnalysis(n_components = 2)
LDA_OPT.fit(x_train_15, y_train)

X = LDA_15.transform(x_train_15)

CLF_OPT = Perceptron()
CLF_OPT.fit(X, y_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#            fit_intercept=True, max_iter=1000, n_iter_no_change=5, n_jobs=None,
#            penalty=None, random_state=0, shuffle=True, tol=0.001,
#            validation_fraction=0.1, verbose=0, warm_start=False)

# %%
X_TEST_15 = LDA_OPT.transform(x_test_15)
Y_TEST = CLF_OPT.predict(X_TEST_15)

# %%
Y_TEST
# Out:
# array([1, 0, 0, 0, 2, 0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 2, 2, 2, 0, 0, 0, 0,
#        0, 2, 2, 0, 2, 1, 0, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 2,
#        0, 0, 2, 0, 0, 0, 2, 0, 1, 2, 1, 0, 0, 0, 2, 2, 1, 2, 0, 0, 2, 2,
#        0, 0, 0, 2, 0, 1, 2, 2, 2, 2, 0, 1, 0, 1, 2, 0, 2, 0, 0, 0, 2, 2,
#        0, 2, 0, 0, 0, 1, 2, 0, 1, 0, 0, 0])

# %% [markdown]
# Scatter the reduced feature matrix of degree = 15 of testset according to the predicted class.

# %%
plt.scatter(X_TEST_15[:, 0], X_TEST_15[:, 1], c = Y_TEST)
plt.show()

# %% [markdown]
# Scatter the reduced feature matrices of each degree of trainset according to the true class.

# %%
plt.figure(figsize = (11, 11), dpi = 100)

plt.subplot(3, 2, 1)
plt.scatter(X_TRAIN_5[:, 0], X_TRAIN_5[:, 1], c = y_train)

plt.title('Degree = 5')

plt.subplot(3, 2, 2)
plt.scatter(X_TRAIN_10[:, 0], X_TRAIN_10[:, 1], c = y_train)
plt.title('Degree = 10')

plt.subplot(3, 2, 3)
plt.scatter(X_TRAIN_15[:, 0], X_TRAIN_15[:, 1], c = y_train)
plt.title('Degree = 15')

plt.subplot(3, 2, 4)
plt.scatter(X_TRAIN_20[:, 0], X_TRAIN_20[:, 1], c = y_train)
plt.title('Degree = 20')

plt.subplot(3, 2, 5)
plt.scatter(X_TRAIN_25[:, 0], X_TRAIN_25[:, 1], c = y_train)
plt.title('Degree = 25')

plt.show()
